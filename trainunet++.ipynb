# %%
pwd
# Out:
# '/content'

# %%
# %cd ../..
# Out:
# /

# %%
# %cd /content/drive/MyDrive/553project/
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/553project/'
# /

# %%
# %cd Data_augmented-20240416T234324Z-001/Data_augmented/
# Out:
# /content/drive/MyDrive/553project/Data_augmented-20240416T234324Z-001/Data_augmented

# %%
# !ls
# Out:
# GroundTruth_augmented	   TissueImages_color_normalized_augmented
# GroundTruth_augmented.zip  TissueImages_color_normalized_augmented.zip
# __MACOSX

# %%
# !unzip GroundTruth_augmented.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: GroundTruth_augmented/4888.png
#   inflating: GroundTruth_augmented/4650.png
#   inflating: GroundTruth_augmented/3659.png
#   inflating: GroundTruth_augmented/4136.png
#   inflating: GroundTruth_augmented/3881.png
#   inflating: GroundTruth_augmented/5228.png
#   inflating: GroundTruth_augmented/2547.png
#   inflating: GroundTruth_augmented/10000.png
#   inflating: GroundTruth_augmented/6721.png
#   inflating: GroundTruth_augmented/9412.png
#   inflating: GroundTruth_augmented/6912.png
#   inflating: GroundTruth_augmented/531.png
#   inflating: GroundTruth_augmented/4863.png
#   inflating: GroundTruth_augmented/257.png
#   inflating: GroundTruth_augmented/8081.png
#   inflating: GroundTruth_augmented/243.png
#   inflating: GroundTruth_augmented/8095.png
#   inflating: GroundTruth_augmented/4877.png
#   inflating: GroundTruth_augmented/10799.png
#   inflating: GroundTruth_augmented/6906.png
# ...

# %%
import os
path ="GroundTruth_augmented"  #文件夹路径
count = 0
for file in os.listdir(path): #file 表示的是文件名
        count = count+1
print(count)
# Out:
# 10830

# %%
from PIL import Image
Image.open('/content/drive/MyDrive/553project/Data_augmented-20240416T234324Z-001/Data_augmented/GroundTruth_augmented/4673.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=96x96>

# %%
# %matplotlib inline
# !python3 train.py
# Out:
# epoch 1 --- loss 0.071 ---  train acc 0.878 --- test acc 0.221 --- cost time 34.77990460395813
# epoch 2 --- loss 0.061 ---  train acc 0.897 --- test acc 0.187 --- cost time 69.35438919067383
# epoch 3 --- loss 0.057 ---  train acc 0.903 --- test acc 0.218 --- cost time 103.88765740394592

# %%
# !pip install d2l
